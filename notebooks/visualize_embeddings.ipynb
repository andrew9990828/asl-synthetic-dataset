# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import torch

# TODO after model training:
# Load embeddings and plot them

print("Embedding visualization notebook placeholder.")
